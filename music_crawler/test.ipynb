# %%
from ..machine_learning.predict import predict_

audio = '/home/khangpt/MUSIC-GEN-PROJ/user_song/-mp3convert.org.mp3'
print(predict_(audio))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from ..machine_learning.predict import predict_
#       3 audio = '/home/khangpt/MUSIC-GEN-PROJ/user_song/-mp3convert.org.mp3'
#       4 print(predict_(audio))
#
# ImportError: attempted relative import with no known parent package
